# %% [markdown]
# # DIGITAL_IMAGE_PROCESSING_LAB_WORKSHEET_1

# %% [markdown]
# Basic concept of digital image processing  to read display an image using cv2 , matplotlib, PIL

# %% [markdown]
# # 1.Reading and display of image using PIL

# %%
# Importing PIL Module
from PIL import Image

# %%
# Reading  Image from localfile

img = Image.open('./amanpreet.jpeg')

# %%
# Display the Image

img.show()

#this show the image by open image in folder

# %% [markdown]
# # 2.Reading and display of image using Matplotlib

# %% [markdown]
# ## 2.1 Matlibplot Module

# %%
#Import matplotlib module
import matplotlib.pyplot as plt

# %%
# Reading  Image from localfile

img = plt.imread('./photoofme.jpg')

# %%
# using matplotlib to display the image

plt.imshow(img)

# %% [markdown]
# ## 2.2 Using Matplotlib Image module

# %%
# Import library

import matplotlib.image as mpimg

# %%
#Read the Image , which is in the same foulder

img = mpimg.imread('./photoofme.jpg')

# %%
# Displaying the image using matplotlib

plt.imshow(img)

# %% [markdown]
# # 3.READING AND DISPLAY OF IMAGE USING OPEN CV2

# %%
# Import OpenCV Module

import cv2 as cv

# %%
# Read the Image

img = cv.imread('./photoofme.jpg',1)

# RESIZE IMAGE TO FIT IN SCREEN
scale_percent = 20 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
img_res = cv.resize(img, dim, interpolation = cv.INTER_AREA)

# %%
# Display the image using openCV

cv.imshow('windowTitle', img_res)

#this command show the image in the window page

# %%
# Display the image until you press any key
cv.waitKey(0)
